# %%
#from google.colab import drive
#drive.mount('/content/gdrive') #, force_remount=True

# %%
#import os
#os.chdir('gdrive/My Drive/Colab Notebooks')

# %% [markdown]
# # annot df

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('все сегментации.xlsx')

# %%
df.head(10)
# Out:
#                                                   зс  \
# 0                               Да, очень раздражает
# 1  и утомляет все время сортировать мусор правильно.
# 2       На кухне воняют три разных мешка для мусора.
# 3     Их нужно отсортировать в разные мусорные баки.
# 4  Но все же Германия производит слишком много му...
# 5                 и теряется слишком много ресурсов,
# 6  когда сжигается то, что на самом деле следует ...
# 7  Мы, берлинцы, должны воспользоваться шансом и ...
# 8                                                NaN
# 9  Медицинские страховые компании не должны покры...
#
#                                             no rules  \
# 0                               Да, очень раздражает
# 1  и утомляет все время сортировать мусор правильно.
# 2       На кухне воняют три разных мешка для мусора.
# 3     Их нужно отсортировать в разные мусорные баки.
# 4  Но все же Германия производит слишком много му...
# 5                 и теряется слишком много ресурсов,
# 6  когда сжигается то, что на самом деле следует ...
# 7                                  и перерабатывать.
# 8        Мы, берлинцы, должны воспользоваться шансом
# 9      и стать первопроходцами в разделении отходов!
#
#                                               rule_1  \
# 0                               Да, очень раздражает
# 1  и утомляет все время сортировать мусор правильно.
# 2       На кухне воняют три разных мешка для мусора.
# 3     Их нужно отсортировать в разные мусорные баки.
# 4  Но все же Германия производит слишком много му...
# 5                 и теряется слишком много ресурсов,
# 6  когда сжигается то, что на самом деле следует ...
# 7                                  и перерабатывать.
# 8        Мы, берлинцы, должны воспользоваться шансом
# 9      и стать первопроходцами в разделении отходов!
#
#                                               rule_2  \
# 0                               Да, очень раздражает
# 1  и утомляет все время сортировать мусор правильно.
# 2       На кухне воняют три разных мешка для мусора.
# 3     Их нужно отсортировать в разные мусорные баки.
# 4  Но все же Германия производит слишком много му...
# 5                 и теряется слишком много ресурсов,
# 6  когда сжигается то, что на самом деле следует ...
# 7                                  и перерабатывать.
# 8        Мы, берлинцы, должны воспользоваться шансом
# 9      и стать первопроходцами в разделении отходов!
#
#                                        rule_1__rule2
# 0                               Да, очень раздражает
# 1  и утомляет все время сортировать мусор правильно.
# 2       На кухне воняют три разных мешка для мусора.
# 3     Их нужно отсортировать в разные мусорные баки.
# 4  Но все же Германия производит слишком много му...
# 5                 и теряется слишком много ресурсов,
# 6  когда сжигается то, что на самом деле следует ...
# 7                                  и перерабатывать.
# 8        Мы, берлинцы, должны воспользоваться шансом
# 9      и стать первопроходцами в разделении отходов!

# %%
df.columns.tolist()
# Out:
# ['id текста',
#  'полина',
#  'кеша',
#  'даша',
#  'зс',
#  'Полина и Кеша',
#  'Кеша и Даша',
#  'согласие у всех',
#  'comment - С.Ю.',
#  'comment',
#  'Unnamed: 10']

# %%
df = df.drop(['Полина и Кеша','comment - С.Ю.', 'согласие у всех'], axis = 1)

# %%
df = df.dropna(how='all')

# %%
df['кеша'] = df['кеша'].fillna('None')
df['полина'] = df['полина'].fillna('None')
df['даша'] = df['даша'].fillna('None')

# %%
df['id текста'] = df['id текста'].astype('int')

# %%
df = df.drop(df[df['id текста'] == 10].index)

# %%
df.tail()
# Out:
#      id текста полина                                               кеша  \
# 349         51   None  Но нанимаются в основном временные сотрудники ...
# 350         51   None  так что это практически не влияет на уровень з...
# 351         51   None  Более того, частная и семейная жизнь сильно ст...
# 352         51   None  К тому же, только большие компании могут позво...
# 353         51   None  По этим причинам нельзя допускать, чтобы супер...
#
#      даша   зс  Кеша и Даша comment Unnamed: 10
# 349  None  NaN          NaN     NaN         NaN
# 350  None  NaN          NaN     NaN         NaN
# 351  None  NaN          NaN     NaN         NaN
# 352  None  NaN          NaN     NaN         NaN
# 353  None  NaN          NaN     NaN         NaN

# %% [markdown]
# # 1 text example

# %%
df_text1 = df[df['id текста'] == 1]

# %%
df_text1
# Out:
#    id текста                                             полина  \
# 0          1  Да, очень раздражает и утомляет все время сорт...
# 1          1                                               None
# 2          1       На кухне воняют три разных мешка для мусора.
# 3          1     Их нужно отсортировать в разные мусорные баки.
# 4          1  Но все же Германия производит слишком много му...
# 5          1                 и теряется слишком много ресурсов,
# 6          1  когда сжигается то, что на самом деле следует ...
# 7          1        Мы, берлинцы, должны воспользоваться шансом
# 8          1      и стать первопроходцами в разделении отходов!
#
#                                                 кеша  \
# 0  Да, очень раздражает и утомляет все время сорт...
# 1                                               None
# 2       На кухне воняют три разных мешка для мусора.
# 3     Их нужно отсортировать в разные мусорные баки.
# 4  Но все же Германия производит слишком много му...
# 5                 и теряется слишком много ресурсов,
# 6  когда сжигается то, что на самом деле следует ...
# 7        Мы, берлинцы, должны воспользоваться шансом
# 8      и стать первопроходцами в разделении отходов!
#
#                                                 даша  \
# 0                               Да, очень раздражает
# 1  и утомляет все время сортировать мусор правильно.
# 2       На кухне воняют три разных мешка для мусора.
# 3     Их нужно отсортировать в разные мусорные баки.
# 4  Но все же Германия производит слишком много му...
# 5                 и теряется слишком много ресурсов,
# 6  когда сжигается то, что на самом деле следует ...
# 7  Мы, берлинцы, должны воспользоваться шансом и ...
# 8                                               None
#
#                                                   зс  Кеша и Даша comment  \
# 0                               Да, очень раздражает          1.0     NaN
# 1  и утомляет все время сортировать мусор правильно.          1.0     NaN
# 2       На кухне воняют три разных мешка для мусора.          0.0     NaN
# 3     Их нужно отсортировать в разные мусорные баки.          0.0     NaN
# 4  Но все же Германия производит слишком много му...          0.0     NaN
# 5                 и теряется слишком много ресурсов,          0.0     NaN
# 6  когда сжигается то, что на самом деле следует ...          0.0     NaN
# 7  Мы, берлинцы, должны воспользоваться шансом и ...          1.0     NaN
# 8                                                NaN          1.0     NaN
#
#   Unnamed: 10
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN

# %%
df_text1.shape
# Out:
# (9, 8)

# %%
annots = ['полина','кеша','даша']

# %%
for index, row in df_text1.iterrows():
  print(index)
  print(row[annots[0]])
  print(row[annots[1]])
  print(row[annots[2]])
  print("\n")
# Out:
# 0
# Да, очень раздражает и утомляет все время сортировать мусор правильно.
# Да, очень раздражает и утомляет все время сортировать мусор правильно.
# Да, очень раздражает
#
#
# 1
# None
# None
# и утомляет все время сортировать мусор правильно.
#
#
# 2
# На кухне воняют три разных мешка для мусора.
# На кухне воняют три разных мешка для мусора.
# На кухне воняют три разных мешка для мусора.
#
#
# 3
# Их нужно отсортировать в разные мусорные баки.
# Их нужно отсортировать в разные мусорные баки.
# Их нужно отсортировать в разные мусорные баки.
#
#
# 4
# Но все же Германия производит слишком много мусора
# Но все же Германия производит слишком много мусора
# Но все же Германия производит слишком много мусора
#
#
# 5
# и теряется слишком много ресурсов,
# и теряется слишком много ресурсов,
# и теряется слишком много ресурсов,
#
#
# 6
# когда сжигается то, что на самом деле следует разделять и перерабатывать.
# когда сжигается то, что на самом деле следует разделять и перерабатывать.
# когда сжигается то, что на самом деле следует разделять и перерабатывать.
#
#
# 7
# Мы, берлинцы, должны воспользоваться шансом
# Мы, берлинцы, должны воспользоваться шансом
# Мы, берлинцы, должны воспользоваться шансом и стать первопроходцами в разделении отходов!
#
#
# 8
# и стать первопроходцами в разделении отходов!
# и стать первопроходцами в разделении отходов!
# None

# %%
total_agree = []
agree = disagree = 0
for index, row in df_text1.iterrows():
  if row[annots[0]] == row[annots[1]] and row[annots[0]] == row[annots[2]]:
    agree += 1
  else:
    disagree += 1

#print(agree, disagree)
#print(agree/(agree+disagree))
print(agree/(agree+disagree-1))
# Out:
# 0.625

# %%
import sklearn
from sklearn.metrics import cohen_kappa_score

print(cohen_kappa_score(df_text1[annots[0]], df_text1[annots[1]]))
print(cohen_kappa_score(df_text1[annots[0]], df_text1[annots[2]]))
print(cohen_kappa_score(df_text1[annots[1]], df_text1[annots[2]]))
# Out:
# 1.0
# 0.5199999999999999
# 0.5199999999999999

# %% [markdown]
# # all texts eval

# %%
annots = ['полина','кеша','даша']

# %%
def annot_agree(diff = False):
  agree = disagree = 0
  for index, row in df.iterrows():
    if row[annots[0]] == row[annots[1]] and row[annots[0]] == row[annots[2]]:
      agree += 1
    else:
      disagree += 1
      if diff == True:
        print(f'row_id = {index}, text_id = {row["id текста"]}')
        for i in annots:
          print(f'{i}: {row[i]}')
        print('\n')
      else:
        continue
  return agree/(agree+disagree-1)

# %%
annot_agree(diff=True)
# Out:
# row_id = 0, text_id = 1
# полина: Да, очень раздражает и утомляет все время сортировать мусор правильно.
# кеша: Да, очень раздражает и утомляет все время сортировать мусор правильно.
# даша: Да, очень раздражает
#
#
# row_id = 1, text_id = 1
# полина: None
# кеша: None
# даша: и утомляет все время сортировать мусор правильно.
#
#
# row_id = 7, text_id = 1
# полина: Мы, берлинцы, должны воспользоваться шансом
# кеша: Мы, берлинцы, должны воспользоваться шансом
# даша: Мы, берлинцы, должны воспользоваться шансом и стать первопроходцами в разделении отходов!
#
#
# row_id = 8, text_id = 1
# полина: и стать первопроходцами в разделении отходов!
# кеша: и стать первопроходцами в разделении отходов!
# даша: None
#
#
# row_id = 26, text_id = 5
# полина: Их оборудование, данные и опыт в течение долгого времени использовались,
# кеша: None
# даша: Их оборудование, данные и опыт в течение долгого времени использовались,
#
#
# row_id = 27, text_id = 5
# полина: чтобы держать нас под надзором.
# кеша: None
# даша: чтобы держать нас под надзором.
#
#
# row_id = 43, text_id = 8
# полина: Конечно, было бы замечательно, если после хорошей ночи с встреченным на вечеринке знакомым можно было просто принять противозачаточное и почувствовать облегчение.
# кеша: Конечно, было бы замечательно,
# даша: Конечно, было бы замечательно,
#
#
# row_id = 44, text_id = 8
# полина: None
# кеша: если после хорошей ночи с встреченным на вечеринке знакомым можно было просто принять противозачаточное
# даша: если после хорошей ночи с встреченным на вечеринке знакомым можно было просто принять противозачаточное
#
#
# row_id = 45, text_id = 8
# полина: None
# кеша: и почувствовать облегчение.
# даша: и почувствовать облегчение.
#
#
# row_id = 77, text_id = 13
# полина: - а кто будет ставить под сомнение их объём опыта?
# кеша: — а кто будет ставить под сомнение их объём опыта?
# даша: — а кто будет ставить под сомнение их объём опыта?
#
#
# row_id = 98, text_id = 16
# полина: где продуктивность должна проявляться не в единичном случае, а постоянно и  в течение долгого времени.
# кеша: где продуктивность должна проявляться не в единичном случае, а постоянно и в течение долгого времени.
# даша: где продуктивность должна проявляться не в единичном случае, а постоянно и в течение долгого времени.
#
#
# row_id = 106, text_id = 17
# полина: но кажется неправдоподобным то, что люди с неизменным доходом внезапно должны платить больше
# кеша: но кажется неправдоподобным то,
# даша: но кажется неправдоподобным то, что люди с неизменным доходом внезапно должны платить больше
#
#
# row_id = 107, text_id = 17
# полина: None
# кеша: что люди с неизменным доходом внезапно должны платить больше
# даша: None
#
#
# row_id = 115, text_id = 18
# полина: Следовательно, страховые компании не должны покрывать расходы ни на какие недоказанные и непризнанные методы лечения, предлагаемые натуропатами.
# кеша: Следовательно, страховые компании не должны покрывать расходы ни на какие недоказанные и непризнанные методы лечения, предлагаемые натуропатами.
# даша: Следовательно, страховые компании не должны покрывать расходы ни на какие недоказанные и непризнанные методы лечения,
#
#
# row_id = 116, text_id = 18
# полина: None
# кеша: None
# даша: предлагаемые натуропатами.
#
#
# row_id = 119, text_id = 19
# полина: Те, кто делает это или пытаются, должны по возможности быть привлечены к ответственности.
# кеша: Те, кто делает это или пытаются, должны по возможности быть привлечены к ответственности.
# даша: Те, кто делает это
#
#
# row_id = 120, text_id = 19
# полина: None
# кеша: None
# даша: или пытаются,
#
#
# row_id = 121, text_id = 19
# полина: None
# кеша: None
# даша: должны по возможности быть привлечены к ответственности.
#
#
# row_id = 149, text_id = 23
# полина: Каждый человек, даже совершивший ужасное преступление, может раскаться в содеянном
# кеша: Каждый человек, даже совершивший ужасное преступление, может раскаться в содеянном и измениться.
# даша: Каждый человек,
#
#
# row_id = 150, text_id = 23
# полина: None
# кеша: None
# даша: даже совершивший ужасное преступление,
#
#
# row_id = 151, text_id = 23
# полина: None
# кеша: None
# даша: может раскаться в содеянном
#
#
# row_id = 152, text_id = 23
# полина: и измениться.
# кеша: None
# даша: и измениться.
#
#
# row_id = 206, text_id = 31
# полина: поскольку никто не может претендовать на право решать, жить другому или умереть.
# кеша: поскольку никто не может претендовать на право решать, жить другому или умереть.
# даша: поскольку никто не может претендовать на право решать, жить другому
#
#
# row_id = 207, text_id = 31
# полина: None
# кеша: None
# даша: или умереть.
#
#
# row_id = 209, text_id = 31
# полина: Каждому должен быть предоставлен шанс пробудить свою совесть
# кеша: Каждому должен быть предоставлен шанс пробудить свою совесть и, возможно,
# даша: Каждому должен быть предоставлен шанс пробудить свою совесть
#
#
# row_id = 210, text_id = 31
# полина: и, возможно, искупить вину за содеянное.
# кеша: искупить вину за содеянное.
# даша: и, возможно, искупить вину за содеянное.
#
#
# row_id = 221, text_id = 33
# полина: Размер поля достаточен для того, чтобы широкое открытое пространство соседствовало с жилыми домами.
# кеша: Размер поля достаточен для того, чтобы широкое открытое пространство соседствовало с жилыми домами.
# даша: Размер поля достаточен
#
#
# row_id = 222, text_id = 33
# полина: None
# кеша: None
# даша: для того, чтобы широкое открытое пространство соседствовало с жилыми домами.
#
#
# row_id = 232, text_id = 35
# полина: Зачастую они менее затратны, чем лекарства, предоставляемые традиционной медициной,
# кеша: Зачастую они менее затратны, чем лекарства, предоставляемые традиционной медициной, которые в конце концов всё равно оплачиваются.
# даша: Зачастую они менее затратны, чем лекарства, предоставляемые традиционной медициной,
#
#
# row_id = 233, text_id = 35
# полина: которые в конце концов всё равно оплачиваются.
# кеша: None
# даша: которые в конце концов всё равно оплачиваются.
#
#
# row_id = 240, text_id = 36
# полина: Активность, требуемая от игроков, значительна
# кеша: Активность, требуемая от игроков, значительна и во всех отношениях сопоставима с физическими нагрузками.
# даша: Активность, требуемая от игроков, значительна
#
#
# row_id = 241, text_id = 36
# полина: и во всех отношениях сопоставима с физическими нагрузками.
# кеша: None
# даша: и во всех отношениях сопоставима с физическими нагрузками.
#
#
# row_id = 245, text_id = 36
# полина: Учитывая их технические условия,
# кеша: Учитывая их технические условия, некоторые видеоигры не относятся к спортивным дисциплинам,
# даша: Учитывая их технические условия,
#
#
# row_id = 246, text_id = 36
# полина: некоторые видеоигры не относятся к спортивным дисциплинам,
# кеша: None
# даша: некоторые видеоигры не относятся к спортивным дисциплинам,
#
#
# row_id = 258, text_id = 38
# полина: Кроме того, это бы облегчило обнаружение прогульщиков,
# кеша: Кроме того, это бы облегчило обнаружение прогульщиков, которым безнаказанно сходит с рук пропуск уроков.
# даша: Кроме того, это бы облегчило обнаружение прогульщиков, которым безнаказанно сходит с рук пропуск уроков.
#
#
# row_id = 259, text_id = 38
# полина: которым безнаказанно сходит с рук пропуск уроков.
# кеша: None
# даша: None
#
#
# row_id = 262, text_id = 38
# полина: которое, возможно, будет усилено одинаковым, общим внешним видом..
# кеша: которое, возможно, будет усилено одинаковым, общим внешним видом.
# даша: которое, возможно, будет усилено одинаковым, общим внешним видом.
#
#
# row_id = 268, text_id = 39
# полина: Конечно, можно утверждать, что страна должна сама разбираться со своими внутренними политическими изменениями,
# кеша: Конечно, можно утверждать,
# даша: Конечно, можно утверждать, что страна должна сама разбираться со своими внутренними политическими изменениями,
#
#
# row_id = 269, text_id = 39
# полина: None
# кеша: что страна должна сама разбираться со своими внутренними политическими изменениями,
# даша: None
#
#
# row_id = 274, text_id = 40
# полина: и это портит настроение на весь день  из-за грязи, вони и часто значительных усилий, необходимых для её удаления.
# кеша: и это портит настроение на весь день из-за грязи, вони и часто значительных усилий, необходимых для её удаления.
# даша: и это портит настроение на весь день из-за грязи, вони и часто значительных усилий, необходимых для её удаления.
#
#
# row_id = 275, text_id = 40
# полина: К тому же, штраф за публичное мочеиспускание для людей выше, чем за оставление собачьих испражнений на асфальте,
# кеша: К тому же, штраф за публичное мочеиспускание для людей выше, чем за оставление собачьих испражнений на асфальте, чего не должно быть.
# даша: К тому же, штраф за публичное мочеиспускание для людей выше, чем за оставление собачьих испражнений на асфальте,
#
#
# row_id = 276, text_id = 40
# полина: чего не должно быть.
# кеша: None
# даша: чего не должно быть.
#
#
# row_id = 292, text_id = 42
# полина: Поскольку воздействие противозачаточных таблеток является настолько сильным,
# кеша: Поскольку воздействие противозачаточных таблеток является настолько сильным, частично из-за абортивного эффекта,
# даша: Поскольку воздействие противозачаточных таблеток является настолько сильным, частично из-за абортивного эффекта,
#
#
# row_id = 293, text_id = 42
# полина: частично из-за абортивного эффекта,
# кеша: None
# даша: None
#
#
# row_id = 295, text_id = 42
# полина: Лёгкий доступ к противозачаточным может так же привести к тому, что они будут казаться более простым методом контрацепции по сравнению с другими, оказывающими меньшее воздействие на здоровье.
# кеша: Лёгкий доступ к противозачаточным может так же привести к тому,
# даша: Лёгкий доступ к противозачаточным может так же привести к тому, что они будут казаться более простым методом контрацепции по сравнению с другими, оказывающими меньшее воздействие на здоровье.
#
#
# row_id = 296, text_id = 42
# полина: None
# кеша: что они будут казаться более простым методом контрацепции по сравнению с другими, оказывающими меньшее воздействие на здоровье.
# даша: None
#
#
# row_id = 297, text_id = 42
# полина: Например, эти таблетки могут привести к сокращению использования презервативов и, следовательно, к учащению случаев заражения СПИДом.
# кеша: Например, эти таблетки могут привести к сокращению использования презервативов и, следовательно, к учащению случаев заражения СПИДом.
# даша: Например, эти таблетки могут привести к сокращению использования презервативов и, следовательно, к учащению случаев заражения СПИДом.
#
#
# row_id = 306, text_id = 45
# полина: Покупая незаконно приобретённую налоговую информацию о горожанах, государство не только само нарушает закон,
# кеша: Покупая незаконно приобретённую налоговую информацию о горожанах, государство не только само нарушает закон,
# даша: Покупая незаконно приобретённую налоговую информацию о горожанах,
#
#
# row_id = 307, text_id = 45
# полина: None
# кеша: None
# даша: государство не только само нарушает закон,
#
#
# row_id = 312, text_id = 45
# полина: Неоспоримо, однако, что, приобретая такие данные, государство усиливает давление на лиц, уклоняющихся от уплаты налогов,
# кеша: Неоспоримо, однако, что, приобретая такие данные, государство усиливает давление на лиц, уклоняющихся от уплаты налогов,
# даша: Неоспоримо, однако, что,
#
#
# row_id = 313, text_id = 45
# полина: None
# кеша: None
# даша: приобретая такие данные,
#
#
# row_id = 314, text_id = 45
# полина: None
# кеша: None
# даша: государство усиливает давление на лиц, уклоняющихся от уплаты налогов,
#
#
# row_id = 348, text_id = 51
# полина: None
# кеша: В связи с увеличением часов работы в праздничные дни и по воскресеньям наблюдается рост занятости.
# даша: None
#
#
# row_id = 349, text_id = 51
# полина: None
# кеша: Но нанимаются в основном временные сотрудники (студенты, ученики школ и т.д.),
# даша: None
#
#
# row_id = 350, text_id = 51
# полина: None
# кеша: так что это практически не влияет на уровень занятости, на полный рабочий день и количество безработных.
# даша: None
#
#
# row_id = 351, text_id = 51
# полина: None
# кеша: Более того, частная и семейная жизнь сильно страдают из-за сокращения и смещения общепринятых выходных.
# даша: None
#
#
# row_id = 352, text_id = 51
# полина: None
# кеша: К тому же, только большие компании могут позволить себе расходы на увеличение штата.
# даша: None
#
#
# row_id = 353, text_id = 51
# полина: None
# кеша: По этим причинам нельзя допускать, чтобы супермаркеты и торговые центры работали по произвольно выбранным выходным и праздникам.
# даша: None
# 0.8087248322147651

# %%
import sklearn
from sklearn.metrics import cohen_kappa_score

print(cohen_kappa_score(df[annots[0]], df[annots[1]]))
print(cohen_kappa_score(df[annots[0]], df[annots[2]]))
print(cohen_kappa_score(df[annots[1]], df[annots[2]]))
# Out:
# 0.8719211822660098
# 0.8889851485148514
# 0.8453042402429423

# %% [markdown]
# # deeppavlov

# %% [markdown]
# Тут я просто устанавливаю deeppavlov и чекаю его работу

# %%
# !pip install deeppavlov
# Out:
# Collecting deeppavlov
#   Downloading deeppavlov-0.14.0-py3-none-any.whl (988 kB)
# Requirement already satisfied: pymorphy2==0.8 in c:\anaconda\lib\site-packages (from deeppavlov) (0.8)
# Collecting numpy==1.18.0
#   Downloading numpy-1.18.0-cp37-cp37m-win_amd64.whl (12.8 MB)
# Collecting sacremoses==0.0.35
#   Downloading sacremoses-0.0.35.tar.gz (859 kB)
# Collecting pydantic==1.3
#   Downloading pydantic-1.3-py36.py37.py38-none-any.whl (85 kB)
# Collecting ruamel.yaml==0.15.100
#   Downloading ruamel.yaml-0.15.100-cp37-cp37m-win_amd64.whl (225 kB)
# Requirement already satisfied: prometheus-client==0.7.1 in c:\anaconda\lib\site-packages (from deeppavlov) (0.7.1)
# Collecting pandas==0.25.3
#   Downloading pandas-0.25.3-cp37-cp37m-win_amd64.whl (9.2 MB)
# Requirement already satisfied: pytelegrambotapi==3.6.7 in c:\anaconda\lib\site-packages (from deeppavlov) (3.6.7)
# Collecting scikit-learn==0.21.2
#   Downloading scikit_learn-0.21.2-cp37-cp37m-win_amd64.whl (5.9 MB)
# Collecting aio-pika==6.4.1
#   Downloading aio_pika-6.4.1-py3-none-any.whl (40 kB)
# Requirement already satisfied: nltk==3.4.5 in c:\anaconda\lib\site-packages (from deeppavlov) (3.4.5)
# Collecting fastapi==0.47.1
#   Downloading fastapi-0.47.1-py3-none-any.whl (43 kB)
# Requirement already satisfied: filelock==3.0.12 in c:\anaconda\lib\site-packages (from deeppavlov) (3.0.12)
# Collecting overrides==2.7.0
#   Downloading overrides-2.7.0.tar.gz (4.5 kB)
# Requirement already satisfied: pyopenssl==19.1.0 in c:\anaconda\lib\site-packages (from deeppavlov) (19.1.0)
# Requirement already satisfied: scipy==1.4.1 in c:\anaconda\lib\site-packages (from deeppavlov) (1.4.1)
# Requirement already satisfied: pymorphy2-dicts-ru in c:\anaconda\lib\site-packages (from deeppavlov) (2.4.404381.4453942)
# Collecting Cython==0.29.14
#   Downloading Cython-0.29.14-cp37-cp37m-win_amd64.whl (1.7 MB)
# Collecting requests==2.22.0
#   Downloading requests-2.22.0-py2.py3-none-any.whl (57 kB)
# Collecting pytz==2019.1
#   Downloading pytz-2019.1-py2.py3-none-any.whl (510 kB)
# Collecting tqdm==4.41.1
#   Downloading tqdm-4.41.1-py2.py3-none-any.whl (56 kB)
# Collecting rusenttokenize==0.0.5
#   Downloading rusenttokenize-0.0.5-py3-none-any.whl (10 kB)
# Collecting click==7.1.2
#   Downloading click-7.1.2-py2.py3-none-any.whl (82 kB)
# Collecting uvicorn==0.11.7
#   Downloading uvicorn-0.11.7-py3-none-any.whl (43 kB)
# Requirement already satisfied: h5py==2.10.0 in c:\anaconda\lib\site-packages (from deeppavlov) (2.10.0)
# Requirement already satisfied: pymorphy2-dicts<3.0,>=2.4 in c:\anaconda\lib\site-packages (from pymorphy2==0.8->deeppavlov) (2.4.393442.3710985)
# Requirement already satisfied: dawg-python>=0.7 in c:\anaconda\lib\site-packages (from pymorphy2==0.8->deeppavlov) (0.7.2)
# Requirement already satisfied: docopt>=0.6 in c:\anaconda\lib\site-packages (from pymorphy2==0.8->deeppavlov) (0.6.2)
# Requirement already satisfied: six in c:\anaconda\lib\site-packages (from sacremoses==0.0.35->deeppavlov) (1.14.0)
# Requirement already satisfied: joblib in c:\users\иннокентий\appdata\roaming\python\python37\site-packages (from sacremoses==0.0.35->deeppavlov) (0.14.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\anaconda\lib\site-packages (from pandas==0.25.3->deeppavlov) (2.8.1)
# Collecting yarl
#   Downloading yarl-1.6.3-cp37-cp37m-win_amd64.whl (124 kB)
# Collecting aiormq<4,>=3.2.0
#   Downloading aiormq-3.3.1-py3-none-any.whl (28 kB)
# Collecting starlette<=0.12.9,>=0.12.9
#   Downloading starlette-0.12.9.tar.gz (46 kB)
# Requirement already satisfied: cryptography>=2.8 in c:\anaconda\lib\site-packages (from pyopenssl==19.1.0->deeppavlov) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\anaconda\lib\site-packages (from requests==2.22.0->deeppavlov) (2019.11.28)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\anaconda\lib\site-packages (from requests==2.22.0->deeppavlov) (1.25.8)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\anaconda\lib\site-packages (from requests==2.22.0->deeppavlov) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\anaconda\lib\site-packages (from requests==2.22.0->deeppavlov) (3.0.4)
# Collecting websockets==8.*
#   Downloading websockets-8.1-cp37-cp37m-win_amd64.whl (66 kB)
# Collecting h11<0.10,>=0.8
#   Downloading h11-0.9.0-py2.py3-none-any.whl (53 kB)
# Requirement already satisfied: typing-extensions>=3.7.4; python_version < "3.8" in c:\anaconda\lib\site-packages (from yarl->aio-pika==6.4.1->deeppavlov) (3.7.4.3)
# Collecting multidict>=4.0
#   Downloading multidict-5.1.0-cp37-cp37m-win_amd64.whl (48 kB)
# Collecting pamqp==2.3.0
#   Downloading pamqp-2.3.0-py2.py3-none-any.whl (28 kB)
# Requirement already satisfied: cffi!=1.11.3,>=1.8 in c:\anaconda\lib\site-packages (from cryptography>=2.8->pyopenssl==19.1.0->deeppavlov) (1.14.0)
# Requirement already satisfied: pycparser in c:\anaconda\lib\site-packages (from cffi!=1.11.3,>=1.8->cryptography>=2.8->pyopenssl==19.1.0->deeppavlov) (2.19)
# Building wheels for collected packages: sacremoses, overrides, starlette
#   Building wheel for sacremoses (setup.py): started
#   Building wheel for sacremoses (setup.py): finished with status 'done'
#   Created wheel for sacremoses: filename=sacremoses-0.0.35-py3-none-any.whl size=884004 sha256=2ad69bbb2da33bc5839525a4b4057119e064558ac8cb1e6ee73ffc424d4502f5
#   Stored in directory: c:\users\5f40~1\appdata\local\pip\cache\wheels\d1\ff\0e\e00ff1e22100702ac8b24e709551ae0fb29db9ffc843510a64
#   Building wheel for overrides (setup.py): started
#   Building wheel for overrides (setup.py): finished with status 'done'
#   Created wheel for overrides: filename=overrides-2.7.0-py3-none-any.whl size=5607 sha256=c3dabcf25b3abdaee89abaf12e8ad1a1712e9a34735d5f9b97ecff566e783d73
#   Stored in directory: c:\users\5f40~1\appdata\local\pip\cache\wheels\c9\87\45\bfdacf6c3b8233b6e8d519edcbd1cf297ad5ff5f0bf84bb9c1
#   Building wheel for starlette (setup.py): started
#   Building wheel for starlette (setup.py): finished with status 'done'
#   Created wheel for starlette: filename=starlette-0.12.9-py3-none-any.whl size=57247 sha256=ee22d8eb81a998ba5717ed35dfd7be9aeaac94ee404cbbbc307911e382dba824
#   Stored in directory: c:\users\5f40~1\appdata\local\pip\cache\wheels\e8\78\be\f57ed5aed7cd222abdb24e3186b5c9f1074184fcc0a295102b
# Successfully built sacremoses overrides starlette
# Installing collected packages: numpy, click, tqdm, sacremoses, pydantic, ruamel.yaml, pytz, pandas, scikit-learn, multidict, yarl, pamqp, aiormq, aio-pika, starlette, fastapi, overrides, Cython, requests, rusenttokenize, websockets, h11, uvicorn, deeppavlov
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.18.1
#     Uninstalling numpy-1.18.1:
#       Successfully uninstalled numpy-1.18.1
# ERROR: catboost 0.22 requires graphviz, which is not installed.
# ERROR: catboost 0.22 requires plotly, which is not installed.
# ERROR: app-store-scraper 0.3.3 has requirement requests==2.23.0, but you'll have requests 2.22.0 which is incompatible.
# ERROR: Could not install packages due to an EnvironmentError: [WinError 5] Отказано в доступе: 'c:\\anaconda\\lib\\site-packages\\~umpy\\core\\_multiarray_tests.cp37-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.

# %%
# !python -m deeppavlov install syntax_ru_syntagrus_bert
# Out:
# C:\anaconda\python.exe: No module named deeppavlov

# %%
# !python -m deeppavlov install squad_bert
# Out:
# C:\anaconda\python.exe: No module named deeppavlov

# %%
# !pip install tensorflow==1.14
# Out:
# Collecting tensorflow==1.14
#   Downloading tensorflow-1.14.0-cp37-cp37m-win_amd64.whl (68.3 MB)
# Collecting gast>=0.2.0
#   Downloading gast-0.4.0-py3-none-any.whl (9.8 kB)
# Collecting termcolor>=1.1.0
#   Downloading termcolor-1.1.0.tar.gz (3.9 kB)
# Requirement already satisfied: protobuf>=3.6.1 in c:\anaconda\lib\site-packages (from tensorflow==1.14) (3.12.2)
# Collecting tensorflow-estimator<1.15.0rc0,>=1.14.0rc0
#   Downloading tensorflow_estimator-1.14.0-py2.py3-none-any.whl (488 kB)
# Requirement already satisfied: wrapt>=1.11.1 in c:\anaconda\lib\site-packages (from tensorflow==1.14) (1.11.2)
# Requirement already satisfied: wheel>=0.26 in c:\anaconda\lib\site-packages (from tensorflow==1.14) (0.34.2)
# Collecting keras-preprocessing>=1.0.5
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# Collecting keras-applications>=1.0.6
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
# Collecting absl-py>=0.7.0
#   Downloading absl_py-0.11.0-py3-none-any.whl (127 kB)
# Requirement already satisfied: six>=1.10.0 in c:\anaconda\lib\site-packages (from tensorflow==1.14) (1.14.0)
# Collecting astor>=0.6.0
#   Downloading astor-0.8.1-py2.py3-none-any.whl (27 kB)
# Collecting tensorboard<1.15.0,>=1.14.0
#   Downloading tensorboard-1.14.0-py3-none-any.whl (3.1 MB)
# Requirement already satisfied: numpy<2.0,>=1.14.5 in c:\anaconda\lib\site-packages (from tensorflow==1.14) (1.18.0)
# Requirement already satisfied: grpcio>=1.8.6 in c:\anaconda\lib\site-packages (from tensorflow==1.14) (1.34.0)
# Collecting google-pasta>=0.1.6
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Requirement already satisfied: setuptools in c:\anaconda\lib\site-packages (from protobuf>=3.6.1->tensorflow==1.14) (45.2.0.post20200210)
# Requirement already satisfied: h5py in c:\anaconda\lib\site-packages (from keras-applications>=1.0.6->tensorflow==1.14) (2.10.0)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\anaconda\lib\site-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow==1.14) (1.0.0)
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.3.3-py3-none-any.whl (96 kB)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in c:\anaconda\lib\site-packages (from markdown>=2.6.8->tensorboard<1.15.0,>=1.14.0->tensorflow==1.14) (1.5.0)
# Requirement already satisfied: zipp>=0.5 in c:\anaconda\lib\site-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<1.15.0,>=1.14.0->tensorflow==1.14) (2.2.0)
# Building wheels for collected packages: termcolor
#   Building wheel for termcolor (setup.py): started
#   Building wheel for termcolor (setup.py): finished with status 'done'
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4835 sha256=dce8314cfefd4a7180d8063d8b0f052861438c532c5e676ebd5b63d3f87fd92c
#   Stored in directory: c:\users\5f40~1\appdata\local\pip\cache\wheels\3f\e3\ec\8a8336ff196023622fbcb36de0c5a5c218cbb24111d1d4c7f2
# Successfully built termcolor
# Installing collected packages: gast, termcolor, tensorflow-estimator, keras-preprocessing, keras-applications, absl-py, astor, markdown, tensorboard, google-pasta, tensorflow
# Successfully installed absl-py-0.11.0 astor-0.8.1 gast-0.4.0 google-pasta-0.2.0 keras-applications-1.0.8 keras-preprocessing-1.1.2 markdown-3.3.3 tensorboard-1.14.0 tensorflow-1.14.0 tensorflow-estimator-1.14.0 termcolor-1.1.0

# %%
# !pip install russian_tagsets
# Out:
# Collecting russian_tagsets
#   Downloading russian-tagsets-0.6.tar.gz (23 kB)
# Building wheels for collected packages: russian-tagsets
#   Building wheel for russian-tagsets (setup.py): started
#   Building wheel for russian-tagsets (setup.py): finished with status 'done'
#   Created wheel for russian-tagsets: filename=russian_tagsets-0.6-py3-none-any.whl size=24640 sha256=ac1d435413668c094fa2e665b0c3241bb386fece10ce3757feb6974117de97a8
#   Stored in directory: c:\users\5f40~1\appdata\local\pip\cache\wheels\5e\b4\26\9c17a7cdcfc6b8cf43111312f3e7c6abb8e583599e37c422f8
# Successfully built russian-tagsets
# Installing collected packages: russian-tagsets
# Successfully installed russian-tagsets-0.6

# %%
from deeppavlov import build_model, configs
model = build_model("ru_syntagrus_joint_parsing", download=True)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-29-66742ca43535> in <module>
# ----> 1 from deeppavlov import build_model, configs
#       2 model = build_model("ru_syntagrus_joint_parsing", download=True)
#
# ModuleNotFoundError: No module named 'deeppavlov'

# %%
text_parsed = []

sentences = ["Я шёл домой по незнакомой улице.", "Девушка пела в церковном хоре."]
for parse in model(sentences):
  sent_info = []
  row = parse.split('\t_\n')
  for i in row:
    inf = i.split('\t')
    sent_info.append(inf)
  text_parsed.append(sent_info)
  #print(parse, end="\n\n")

# %%
mas = ['001','003','004','005']

# %%
raw_texts = []
for i in mas:
  name = i+'_rus_raw.txt'
  text = open(name, 'r', encoding = 'utf-8').read()
  print(text)
  raw_texts.append(text)

# %%
pip install rusenttokenize

# %%
from rusenttokenize import ru_sent_tokenize

# %%
raw_sents = []
for i in raw_texts:
  raw_sents.append(ru_sent_tokenize(i))

# %%
for i in raw_sents:
  print(i)

# %%
for parse in model(raw_sents[0]):
    print(parse, end="\n\n")

# %% [markdown]
# # text tok

# %%
for index, row in df.iterrows():
  ann0 = row[annots[0]]
  ann1 = row[annots[1]]
  ann2 = row[annots[2]]
  edus = [ann0, ann1, ann2]
  for parse in model(edus):
    print(parse, end="\n\n")

# %%
from deeppavlov import build_model, configs
model = build_model("ru_syntagrus_joint_parsing", download=True)

# %%
text_parsed = []

sentences = ["Я шёл домой по незнакомой улице.", "Девушка пела в церковном хоре."]
for parse in model(sentences):
  sent_info = []
  row = parse.split('\t_\n')
  for i in row:
    inf = i.split('\t')
    sent_info.append(inf)
  text_parsed.append(sent_info)
  #print(parse, end="\n\n")

# %%
annots_parsed = {}#{'полина':[],'кеша':[]}
for index, row in df.iterrows():
  text_parsed = []
  ann0 = row[annots[0]]
  ann1 = row[annots[1]]
  ann2 = row[annots[2]]
  edus = [ann0, ann1, ann2]
  for parse in model(edus):
     sent_info = []
     row = parse.split('\t_\n')
     for i in row:
       inf = i.split('\t')
       sent_info.append(inf)
     text_parsed.append(sent_info)
  for name_id in range(len(annots)):
    if annots[name_id] not in annots_parsed.keys():
      annots_parsed[annots[name_id]] = []
      annots_parsed[annots[name_id]].append(text_parsed[name_id])
    else:
      annots_parsed[annots[name_id]].append(text_parsed[name_id])

# %%
for i in annots_parsed.keys():
  print(i)
  print(len(annots_parsed[i]))

# %%
df.head()

# %%
for name in annots:
  new_col_name = name+'_conllu'
  df[new_col_name] = annots_parsed[name]

# %%
df.head()

# %%
edus_norm = {}
for i in annots_parsed.keys():

  for row in annots_parsed[i]:
    tokens = []
    for j in row:
      tokens.append(j[2])
    row_tok = ' '.join(tokens)
    if i not in edus_norm.keys():
      edus_norm[i] = []
      edus_norm[i].append(row_tok)
    else:
      edus_norm[i].append(row_tok)

# %%
for i in edus_norm.keys():
  print(i)
  print(len(edus_norm[i]))
  print(edus_norm[i][0])

# %%
for name in annots:
  new_col_name = name+'_norm'
  df[new_col_name] = edus_norm[name]

# %%
df.head()

# %%
total_agree = []
agree = disagree = 0
for index, row in df.iterrows():
  if row[annots[0]+'_norm'] == row[annots[1]+'_norm'] and row[annots[0]+'_norm'] == row[annots[2]+'_norm']:
    agree += 1
  else:
    disagree += 1

#print(agree, disagree)
#print(agree/(agree+disagree))
print(agree/(agree+disagree-1))

# %%
import sklearn
from sklearn.metrics import cohen_kappa_score

print(cohen_kappa_score(df[annots[0]+'_norm'], df[annots[1]+'_norm']))
print(cohen_kappa_score(df[annots[0]+'_norm'], df[annots[2]+'_norm']))
print(cohen_kappa_score(df[annots[1]+'_norm'], df[annots[2]+'_norm']))
